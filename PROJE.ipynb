# %% [markdown]
# SORULAR...
#
# PORTLAND, SAN FRANCİSCO, Las_Vegas, SEATTLE, New York --> GENELDE BU ŞEHİRLERİ KULLANALIM.
#
#
#
# -YILLARA GÖRE EYALETLERİN BASINÇ ORTALAMASI.  TİCK
# -Hava Hangi Eyalette Daha Güneşli
# -

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from scipy import stats

import tkinter
from tkinter import ttk #themed tkinter
from tkinter import messagebox
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
city_attributes = pd.read_csv("city_attributes.csv")
humidity = pd.read_csv("humidity.csv")
pressure = pd.read_csv("pressure.csv")
temperature = pd.read_csv("temperature.csv")
weather_description = pd.read_csv("weather_description.csv")
wind_direction = pd.read_csv("wind_direction.csv")
wind_speed = pd.read_csv("wind_speed.csv")

# %%
list = [humidity,pressure,temperature,weather_description,wind_direction,wind_speed]
for i in list:
    i.datetime= i.datetime.apply(pd.to_datetime)

# %%
humidity["month"]=humidity.datetime.dt.month
humidity["year"]=humidity.datetime.dt.year

pressure["month"]=pressure.datetime.dt.month
pressure["year"]=pressure.datetime.dt.year

temperature["month"]=temperature.datetime.dt.month
temperature["year"]=temperature.datetime.dt.year

weather_description["month"]=weather_description.datetime.dt.month
weather_description["year"]=weather_description.datetime.dt.year

wind_direction["month"]=weather_description.datetime.dt.month
wind_direction["year"]=weather_description.datetime.dt.year

wind_speed["month"]=wind_speed.datetime.dt.month
wind_speed["year"]=wind_speed.datetime.dt.year

# %%
broken_clouds = weather_description[weather_description[:]=="broken clouds"].count()
sky_is_clear = weather_description[weather_description[:]=="sky is clear"].count()
scattered_clouds = weather_description[weather_description[:]=="scattered clouds"].count()
few_clouds = weather_description[weather_description[:]=="few clouds"].count()
overcast_clouds = weather_description[weather_description[:]=="overcast_clouds"].count()
light_rain = weather_description[weather_description[:]=="light_rain"].count()
haze = weather_description[weather_description[:]=="haze"].count()
mist = weather_description[weather_description[:]=="mist"].count()

# %%
plt.figure(figsize=(25,40))
plt.subplot(5,1,1)
broken_clouds.plot(kind='bar',color='yellow')
plt.title("broken_clouds days")
plt.ylabel('toplam parçalı bulutlu olma saati/total hours of broken_cloud')
plt.xlabel('state names')
plt.subplot(5,1,2)
sky_is_clear.plot(kind='bar',color='orange')
plt.title("Weather description sky_is_clear")
plt.subplot(5,1,3)
scattered_clouds.plot(kind='bar',color='brown')
plt.title("Weather description scattered_clouds")
plt.subplot(5,1,4)
few_clouds.plot(kind='bar',color='magenta')
plt.title("Weather description few_clouds")
#plt.subplot(5,1,5)
#overcast_clouds.plot(kind='bar',color='blue')
#plt.title("Weather description overcast_clouds")
plt.tight_layout()

# %%
#list = [broken_clouds,"sky_is_clear","scattered_clouds","few_clouds","overcast_clouds"
 #       ,"light_rain","haze","mist"]
list = [broken_clouds,sky_is_clear,scattered_clouds,few_clouds,overcast_clouds
        ,light_rain,haze,mist]
for i in list:
    random = np.random.randint(20, size=1)
    i.iloc[random]
print(random)
i.iloc[random]

# %%
#Our_cities = ["Portland", "San Francisco", "Las Vegas", "Seattle", "New York"]
Portland = ["Portland"]
SanFrancisco = [ "San Francisco"]
LasVegas = [ "Las Vegas"]
Seattle = [ "Seattle"]
NewYork = [ "New York"]
#grouped = pressure.groupby('year').mean()
grouped = pressure.groupby('year').mean()


##CHART YAPILDI!!!!!!!!


#grouped[Our_cities].plot(kind='bar',color='yellow')
plt.figure(figsize=(25,40))
grouped[Portland].plot()
plt.title("Portland")
plt.ylabel('mean of the pressure(on that year)')
plt.xlabel('year')

grouped[SanFrancisco].plot()
plt.title("SanFrancisco")
plt.ylabel('mean of the pressure(on that year)')
plt.xlabel('year')

grouped[LasVegas].plot()
plt.title("LasVegas")
plt.ylabel('mean of the pressure(on that year)')
plt.xlabel('year')

grouped[Seattle].plot()
plt.title("Seattle")
plt.ylabel('mean of the pressure(on that year)')
plt.xlabel('year')

grouped[NewYork].plot()
plt.title("NewYork")
plt.ylabel('mean of the pressure(on that year)')
plt.xlabel('year')

# %%
#gui oluşturalım graphlerimizi göstermek için

# %%
root = tkinter.Tk()
text1=tkinter.StringVar(root,value="Choose a graph to see:")

def changeText(self,mytext):
    
    self.configure(text=mytext) 
    
def clicked():
    messagebox.showinfo("Title","Button is clicked!")

def clicked2(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    grouped[Portland].plot( legend=True, ax=ax1)
    plt.title("Portland")
    plt.ylabel('mean of the pressure(on that year)')
    plt.xlabel('year')
    ax1.set_title('PRESSURE GRAPH for Portland')
    
    #messagebox.showinfo("Title","Hi {}".format(name))
def clicked3(name):
    button=ttk.Button(frame2,text="Portland",command=lambda : clicked2("Sezin")).grid(column=1,row=1,columnspan=3)
    button=ttk.Button(frame2,text="SanFrancisco",command=lambda : clicked4("Sezin")).grid(column=6,row=1,columnspan=3)
    button=ttk.Button(frame2,text="LasVegas",command=lambda : clicked7("Sezin")).grid(column=11,row=1,columnspan=3)
    button=ttk.Button(frame2,text="Seattle",command=lambda : clicked8("Sezin")).grid(column=16,row=1,columnspan=3)
    button=ttk.Button(frame2,text="NewYork",command=lambda : clicked9("Sezin")).grid(column=21,row=1,columnspan=3)
    
    
    #messagebox.showinfo("Title","Hi {}".format(name))
def clicked4(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    grouped[SanFrancisco].plot( legend=True, ax=ax1)
    plt.title("SanFrancisco")
    plt.ylabel('mean of the pressure(on that year)')
    plt.xlabel('year')
    ax1.set_title('PRESSURE GRAPH for SanFrancisco')
    
    #messagebox.showinfo("Title","Hi {}".format(name))
    
def clicked5(name):
    
    button=ttk.Button(frame2,text="broken_clouds days graph",command=lambda : clicked6("Sezin")).grid(column=1,row=2,columnspan=3)
    button=ttk.Button(frame2,text="sky_is_clear graph",command=lambda : clicked10("Sezin")).grid(column=3,row=2,columnspan=3)
    button=ttk.Button(frame2,text="scattered_clouds graph",command=lambda : clicked11("Sezin")).grid(column=5,row=2,columnspan=3)
    button=ttk.Button(frame2,text="few_clouds graph",command=lambda : clicked12("Sezin")).grid(column=7,row=2,columnspan=3)

    
def clicked6(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    broken_clouds.plot(kind='bar',color='yellow',legend=True, ax=ax1)
    plt.title("broken_clouds days")
    plt.ylabel('toplam parçalı bulutlu olma saati/total hours of broken_cloud')
    plt.xlabel('state names')
    ax1.set_title('weather graph for broken_cloud')
    
def clicked7(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    grouped[LasVegas].plot( legend=True, ax=ax1)
    plt.title("LasVegas")
    plt.ylabel('mean of the pressure(on that year)')
    plt.xlabel('year')
    ax1.set_title('PRESSURE GRAPH for LasVegas')
    
def clicked8(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    grouped[Seattle].plot( legend=True, ax=ax1)
    plt.title("Seattle")
    plt.ylabel('mean of the pressure(on that year)')
    plt.xlabel('year')
    ax1.set_title('PRESSURE GRAPH for Seattle')

def clicked9(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    grouped[NewYork].plot( legend=True, ax=ax1)
    plt.title("NewYork")
    plt.ylabel('mean of the pressure(on that year)')
    plt.xlabel('year')
    ax1.set_title('PRESSURE GRAPH for NewYork')

def clicked10(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    sky_is_clear.plot(kind='bar',color='yellow',legend=True, ax=ax1)
    plt.title("sky_is_clear")
    plt.ylabel('toplam sky_is_clear olma saati/total hours of sky_is_clear')
    plt.xlabel('state names')
    ax1.set_title('weather graph for sky_is_clear')

def clicked11(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    scattered_clouds.plot(kind='bar',color='yellow',legend=True, ax=ax1)
    plt.title("scattered_clouds days")
    plt.ylabel('toplam scattered_clouds olma saati/total hours of scattered_clouds')
    plt.xlabel('state names')
    ax1.set_title('weather graph for scattered_clouds')
    
def clicked12(name):
    figure1 = plt.figure(figsize=(8,8))
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().grid(row=6,column=0,columnspan=2)
    few_clouds.plot(kind='bar',color='yellow',legend=True, ax=ax1)
    plt.title("few_clouds days")
    plt.ylabel('toplam few_clouds olma saati/total hours of few_clouds')
    plt.xlabel('state names')
    ax1.set_title('weather graph for few_clouds')
    
    
    
root.title("My GUI")
root.geometry("1000x600")
frame1=ttk.Frame(root,borderwidth=2).grid(row=0,column=0,columnspan=3)
frame2=ttk.Frame(root,borderwidth=2).grid(row=1,column=0,columnspan=3)
label1=ttk.Label(frame1,textvariable=text1,foreground="purple",background="gray",padding=15,font=("Helvetica",15))
label1.grid(row=0,column=0,columnspan=2)
#label2=ttk.Label(frame1,text="right",foreground="purple",background="gray",padding=15,font=("Helvetica",15))
#label3=ttk.Label(frame1,text="center",foreground="purple",background="gray",padding=15,font=("Helvetica",15))
#name_entry=ttk.Entry(frame1).grid(row=0,column=4,columnspan=2)
#password_entry=ttk.Entry(frame1,show="*").grid(row=1,column=5,columnspan=2)
#to make this widget(label) visible in main windows, you need to pack method
#label1.grid(row=0,column=0,columnspan=2)
#label2.grid(row=1,column=0,columnspan=3)
#label1.pack(side="left")
#button=ttk.Button(frame2,text="submit",command=clicked).grid(column=0,row=2,columnspan=3)

button=ttk.Button(frame2,text="Pressure graph",command=lambda : clicked3("Sezin")).grid(column=0,row=1,columnspan=3)
button=ttk.Button(frame2,text="Weather Description Graph",command=lambda : clicked5("Sezin")).grid(column=0,row=2,columnspan=3)










root.mainloop()
